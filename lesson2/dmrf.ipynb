# %% [markdown]
# # Задание
# * Собрать информацию о всех строящихся объектах на сайте "наш.дом.рф"
# * Cохранить ее в pandas dataframe
# * Cохранить pandas dataframe в excel
# * Cохранить pandas dataframe в pickle
# * Cохранить pandas dataframe в БД
#
# # Задание *
# * Написать скрипт, который скачивает фотографии всех строящихся объектов с сайта "наш.дом.рф"

# %%
import requests

# %% [markdown]
# ## Список объектов

# %%
offset_ = 1
limit_ = 5000
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/kn/object?offset={0}&limit={1000}&sortField=devId.devShortCleanNm&sortType=asc&objStatus=0'
res = requests.get(url)
objects_data = res.json()

# %%
objects_data.keys()
# Out:
# dict_keys(['data', 'errcode'])

# %%
objects_data.get('errcode').keys()
# Out:
# '0'

# %%
 objects_data.get('data').get('list')
# Out:
# [{'objId': 13391,
#   'developer': {'devId': 306,
#    'shortName': '2МЕН ГРУПП',
#    'fullName': '2МЕН ГРУПП',
#    'groupName': '2МЕН ГРУПП ДЕВЕЛОПМЕНТ',
#    'orgForm': {'id': 1, 'fullForm': 'Акционерное общество', 'shortForm': 'АО'},
#    'companyGroup': 699421001,
#    'devInn': '7701651356'},
#   'rpdRegionCd': 72,
#   'objAddr': 'г Тюмень, ул Профсоюзная',
#   'objFloorMin': 3,
#   'objFloorMax': 12,
#   'objElemLivingCnt': 44,
#   'objReady100PercDt': '2022-06-30',
#   'objSquareLiving': 4293.67,
#   'objCompensFundFlg': 1,
#   'objProblemFlg': 0,
#   'latitude': 57.1541,
#   'longitude': 65.5595,
#   'problemFlag': 'NONE',
#   'siteStatus': 'Строящиеся',
#   'objGuarantyEscrowFlg': 0,
#   'residentialBuildings': 1,
#   'rpdNum': '72-000096',
#   'pdId': 28101,
#   'buildType': 'Жилое',
#   'objStatus': 0},
#  {'objId': 13397,
#   'developer': {'devId': 306,
#    'shortName': '2МЕН ГРУПП',
#    'fullName': '2МЕН ГРУПП',
#    'groupName': '2МЕН ГРУПП ДЕВЕЛОПМЕНТ',
# ...

# %%
objects_list = objects_data.get('data').get('list')

# %%
objids = [x.get('objId') for x in objects_list]

# %%
# Out:
# [3796, 5141, 5516, 5525, 5527, 5666, 6070, 6071, 7822, 10941]

# %% [markdown]
# # Данные по определенному объекту

# %%
url = f'https://xn--80az8a.xn--d1aqf.xn--p1ai/%D1%81%D0%B5%D1%80%D0%B2%D0%B8%D1%81%D1%8B/api/object/36774'

# %%
res = requests.get(url)
res.json()
# Out:
# {'data': {'id': 36774,
#   'pdId': 351714,
#   'developer': {'devId': 6926,
#    'devShortCleanNm': 'ОКЕАН',
#    'devShortNm': 'ОКЕАН',
#    'devFullCleanNm': 'ОКЕАН',
#    'problObjCnt': 0,
#    'buildObjCnt': 1,
#    'comissObjCnt': 0,
#    'regRegionDesc': 'Башкортостан Республика',
#    'devPhoneNum': '+7(927)300-31-01',
#    'devSite': 'altun-yar.ru',
#    'devEmail': 'khabibovr@mail.ru',
#    'devInn': '0277093608',
#    'devOgrn': '1080277004521',
#    'devKpp': '027701001',
#    'devLegalAddr': 'Башкортостан Республика, город Уфа, проспект Проспект Октября дом 85',
#    'devFactAddr': 'Респ Башкортостан Город Уфа Проспект Октября д. 85',
#    'lastRpdId': 511041,
#    'fundGuarantyFlg': 0,
#    'devOrgRegRegionCd': 2,
#    'devEmplMainFullNm': 'Хабибов Рамиль Хамидуллович',
#    'developerGroupName': 'Океан',
#    'orgForm': {'id': 4,
#     'fullForm': 'Общество с ограниченной ответственностью',
#     'shortForm': 'ООО'},
#    'companyGroupId': 5767476001,
# ...

# %%
import pandas as pd

# %%
df = pd.json_normalize(pd.DataFrame(objects_list).developer)

# %%
df
# Out:
#       devId       shortName                                   fullName  \
# 0       306      2МЕН ГРУПП                                 2МЕН ГРУПП
# 1       306      2МЕН ГРУПП                                 2МЕН ГРУПП
# 2       306      2МЕН ГРУПП                                 2МЕН ГРУПП
# 3       306      2МЕН ГРУПП                                 2МЕН ГРУПП
# 4      6811       84 ВЫСОТА                                  84 ВЫСОТА
# ...     ...             ...                                        ...
# 4995   6532  СЗ МЕТА-АКАДЕМ  СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК МЕТА-АКАДЕМ
# 4996   6532  СЗ МЕТА-АКАДЕМ  СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК МЕТА-АКАДЕМ
# 4997   6532  СЗ МЕТА-АКАДЕМ  СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК МЕТА-АКАДЕМ
# 4998   6532  СЗ МЕТА-АКАДЕМ  СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК МЕТА-АКАДЕМ
# 4999   6532  СЗ МЕТА-АКАДЕМ  СПЕЦИАЛИЗИРОВАННЫЙ ЗАСТРОЙЩИК МЕТА-АКАДЕМ
#
#                    groupName  companyGroup      devInn  orgForm.id  \
# ...
